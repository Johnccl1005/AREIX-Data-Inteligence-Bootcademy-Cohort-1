# %% [markdown]
# <hr style="margin-bottom: 40px;">
#
# # Principal - Backtesting

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## (A) (B) Simplified

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

df = pd.read_excel("Principal1.xlsx", parse_dates=True, index_col="date")
df.apply(pd.to_numeric, errors='ignore')
df = df.rename(columns=lambda x: x.strip())
df = df.dropna(axis="index",how="all") #drop NaN values. The earliest data starts from 2001-11-20.

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import plotting
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.expected_returns import mean_historical_return

# %%
describe = df.describe()
describe = pd.DataFrame(describe)
describe = describe.T
describe
# Out:
#                     count       mean       std      min     25%       50%  \
# PRSSCOA HK Equity   741.0  11.082049  0.480004   9.5597  10.773  11.02700
# PRIHDSC HK Equity  4022.0  10.700473  0.290911  10.0390  10.337  10.86945
#
#                        75%      max
# PRSSCOA HK Equity  11.3824  12.2271
# PRIHDSC HK Equity  10.9131  11.0834

# %%
# get a list of all the column names 
indexNamesArr = describe.index.values
# convert ndarray to list
listOfRowIndexLabels = list(indexNamesArr)

coord = [(0.038802, 1.598254),( 0.023617, 0.745137),( 0.025753, 0.802417),( 0.045350, 2.066649),( 0.106415, 0.574546),( 0.053244, 0.432762),( 0.039204, 1.853161),( 0.059571, 0.444722),( 0.024976, 2.706996),( 0.012862, 0.312357),( 0.039587, 2.285998),( 0.001826, 0.044556),( 0.027979, 1.050875),( 0.032775, 1.438767),( 0.040590, 2.009521),( 0.042759, 2.400255)]
labels = listOfRowIndexLabels

def plot_with_labels(coord, labels):
    assert len(coord) == len(labels), 'coord len is not equal to labels len'
    plt.figure(figsize=(10,30))
    plt.xlabel('Mean historic return')
    plt.ylabel('volatility')
    plt.title("Performance of Principal Funds")
    plt
    for i, label in enumerate(labels): #get (0, label)
        x, y = coord[i] #2 dim
        plt.scatter(x, y,)
                #
        plt.annotate(label,
                xy=(x, y), #show point 
                xytext=(5, 2), #show annotate
                textcoords='offset points',
                ha='right',
                va='bottom')
    plt.show()
    
plot_with_labels(coord, labels)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-87ec442d8920> in <module>
#      26     plt.show()
#      27
# ---> 28 plot_with_labels(coord, labels)
#
# <ipython-input-4-87ec442d8920> in plot_with_labels(coord, labels)
#       8
#       9 def plot_with_labels(coord, labels):
# ---> 10     assert len(coord) == len(labels), 'coord len is not equal to labels len'
#      11     plt.figure(figsize=(10,30))
#      12     plt.xlabel('Mean historic return')
#
# AssertionError: coord len is not equal to labels len

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## (C) - Backtesting and Optimization
#
# ### Split training set and test set
#
# 1. Split data in train and test set given a Date (i.e. test set is what happens after 31 July 2020 not included).
#
# 2. Further split train set into train set and validation set (i.e. what happens before 31 July 2020 included) in 6 consecutive time folds.
#
# Then, in order not lo lose the time information, perform the following steps:
#
# one = Train on fold 10,11,12,13 (2010-08-01 to 2014-07-31) –>  Test on fold 14 (2014-08-01 to 2015-07-31)
#
# two = Train on fold 11,12,13,14 –>  Test on fold 15
#
# three = Train on fold 12,13,14,15 –>  Test on fold 16
#
# four = Train on fold 13,14,15,16 –>  Test on fold 17
#
# five = Train on fold 14,15,16,17 –>  Test on fold 18
#
# six = Train on fold 15,16,17,18 –>  Test on fold 19 (2019-08-01 to 2020-07-31)
#
# Compute the average of the accuracies of the 6 test folds.

# %%
S = CovarianceShrinkage(df).ledoit_wolf()
mu = mean_historical_return(df)
from datetime import date
#train sets
one = df[(df.index > pd.Timestamp(date(2004,8,1))) & (df.index < pd.Timestamp(date(2005,7,31)))]
two = df[(df.index > pd.Timestamp(date(2005,8,1))) & (df.index < pd.Timestamp(date(2006,7,31)))]
three = df[(df.index > pd.Timestamp(date(2006,8,1))) & (df.index < pd.Timestamp(date(2007,7,31)))]
four = df[(df.index > pd.Timestamp(date(2007,8,1))) & (df.index < pd.Timestamp(date(2008,7,31)))]
five = df[(df.index > pd.Timestamp(date(2008,8,1))) & (df.index < pd.Timestamp(date(2009,7,31)))]
six = df[(df.index > pd.Timestamp(date(2009,8,1))) & (df.index < pd.Timestamp(date(2010,7,31)))]
seven = df[(df.index > pd.Timestamp(date(2010,8,1))) & (df.index < pd.Timestamp(date(2011,7,31)))]
eight = df[(df.index > pd.Timestamp(date(2011,8,1))) & (df.index < pd.Timestamp(date(2012,7,31)))]
nine = df[(df.index > pd.Timestamp(date(2012,8,1))) & (df.index < pd.Timestamp(date(2013,7,31)))]
ten = df[(df.index > pd.Timestamp(date(2013,8,1))) & (df.index < pd.Timestamp(date(2014,7,31)))]
eleven = df[(df.index > pd.Timestamp(date(2014,8,1))) & (df.index < pd.Timestamp(date(2015,7,31)))]
twelve = df[(df.index > pd.Timestamp(date(2015,8,1))) & (df.index < pd.Timestamp(date(2016,7,31)))]
thirteen = df[(df.index > pd.Timestamp(date(2016,8,1))) & (df.index < pd.Timestamp(date(2017,7,31)))]
fourteen = df[(df.index > pd.Timestamp(date(2017,8,1))) & (df.index < pd.Timestamp(date(2018,7,31)))]
fifteen = df[(df.index > pd.Timestamp(date(2018,8,1))) & (df.index < pd.Timestamp(date(2019,7,31)))]
sixteen = df[(df.index > pd.Timestamp(date(2019,8,1))) & (df.index < pd.Timestamp(date(2020,7,31)))]

# %%
#Calculating risk (covariance matrix) for different train periods.
S1 = CovarianceShrinkage(one).ledoit_wolf()
S2 = CovarianceShrinkage(two).ledoit_wolf()
S3 = CovarianceShrinkage(three).ledoit_wolf()
S4 = CovarianceShrinkage(four).ledoit_wolf()
S5 = CovarianceShrinkage(five).ledoit_wolf()
S6 = CovarianceShrinkage(six).ledoit_wolf()
S7 = CovarianceShrinkage(seven).ledoit_wolf()
S8 = CovarianceShrinkage(eight).ledoit_wolf()
S9 = CovarianceShrinkage(nine).ledoit_wolf()
S10 = CovarianceShrinkage(ten).ledoit_wolf()
S11 = CovarianceShrinkage(eleven).ledoit_wolf()
S12 = CovarianceShrinkage(twelve).ledoit_wolf()
S13 = CovarianceShrinkage(thirteen).ledoit_wolf()
S14 = CovarianceShrinkage(fourteen).ledoit_wolf()
S15 = CovarianceShrinkage(fifteen).ledoit_wolf()
S16 = CovarianceShrinkage(sixteen).ledoit_wolf()

'''plot them for the presentation.
plotting.plot_covariance(S1, plot_correlation=True)
plotting.plot_covariance(S2, plot_correlation=True)
plotting.plot_covariance(S3, plot_correlation=True)
plotting.plot_covariance(S4, plot_correlation=True)
plotting.plot_covariance(S5, plot_correlation=True)
plotting.plot_covariance(S6, plot_correlation=True)
'''

#Calculating the expected returns for different train periods.
mu1 = mean_historical_return(one)
mu2 = mean_historical_return(two)
mu3 = mean_historical_return(three)
mu4 = mean_historical_return(four)
mu5 = mean_historical_return(five)
mu6 = mean_historical_return(six)
mu7 = mean_historical_return(seven)
mu8 = mean_historical_return(eight)
mu9 = mean_historical_return(nine)
mu10 = mean_historical_return(ten)
mu11 = mean_historical_return(eleven)
mu12 = mean_historical_return(twelve)
mu13 = mean_historical_return(thirteen)
mu14 = mean_historical_return(fourteen)
mu15 = mean_historical_return(fifteen)
mu16 = mean_historical_return(sixteen)

'''plot and show them for the presentation.
mu1
mu1.plot.barh(figsize=(10,6))
(same for others)
'''
# Out:
# 'plot and show them for the presentation.\nmu1\nmu1.plot.barh(figsize=(10,6))\n(same for others)\n'

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## Function 1a - Portfolio Optimization for maximal Sharpe ratio
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## 1st five-year Backtesting (for Function 1a)
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu1, S1)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-11-0c120fdaea06> in <module>
#       1 ef = EfficientFrontier(mu1, S1)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu1.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-6c81ab2012d7> in <module>
# ----> 1 ret,vol,sharpe = ef.portfolio_performance(verbose=True)
#       2
#       3 mu1.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in portfolio_performance(self, verbose, risk_free_rate)
#     372         :rtype: (float, float, float)
#     373         """
# --> 374         return base_optimizer.portfolio_performance(
#     375             self.weights,
#     376             self.expected_returns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in portfolio_performance(weights, expected_returns, cov_matrix, verbose, risk_free_rate)
#     452         new_weights = np.asarray(weights)
#     453     else:
# --> 454         raise ValueError("Weights is None")
#     455
#     456     sigma = np.sqrt(objective_functions.portfolio_variance(new_weights, cov_matrix))
#
# ValueError: Weights is None

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 2nd five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu2, S2)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-19-e4e63f59758b> in <module>
#       1 ef = EfficientFrontier(mu2, S2)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu2.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7ac10745e8eb> in <module>
# ----> 1 ret,vol,sharpe = ef.portfolio_performance(verbose=True)
#       2
#       3 mu2.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in portfolio_performance(self, verbose, risk_free_rate)
#     372         :rtype: (float, float, float)
#     373         """
# --> 374         return base_optimizer.portfolio_performance(
#     375             self.weights,
#     376             self.expected_returns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in portfolio_performance(weights, expected_returns, cov_matrix, verbose, risk_free_rate)
#     452         new_weights = np.asarray(weights)
#     453     else:
# --> 454         raise ValueError("Weights is None")
#     455
#     456     sigma = np.sqrt(objective_functions.portfolio_variance(new_weights, cov_matrix))
#
# ValueError: Weights is None

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 3rd five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu3, S3)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# OrderedDict([('PRSSCOA HK Equity', 0.0), ('PRIHDSC HK Equity', 1.0)])
# Performance of function 1a portfolio in train period:

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu3.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# Expected annual return: 3.4%
# Annual volatility: 0.3%
# Sharpe Ratio: 4.56

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 4th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu4, S4)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# OrderedDict([('PRSSCOA HK Equity', 0.0), ('PRIHDSC HK Equity', 1.0)])
# Performance of function 1a portfolio in train period:

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu4.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# Expected annual return: 2.7%
# Annual volatility: 0.5%
# Sharpe Ratio: 1.30

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 5th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu5, S5)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-25-292b69459072> in <module>
#       1 ef = EfficientFrontier(mu5, S5)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 6th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu6, S6)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-26-9b98c00272b4> in <module>
#       1 ef = EfficientFrontier(mu6, S6)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu6.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-29557be0aeb8> in <module>
# ----> 1 ret,vol,sharpe = ef.portfolio_performance(verbose=True)
#       2
#       3 mu6.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in portfolio_performance(self, verbose, risk_free_rate)
#     372         :rtype: (float, float, float)
#     373         """
# --> 374         return base_optimizer.portfolio_performance(
#     375             self.weights,
#     376             self.expected_returns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in portfolio_performance(weights, expected_returns, cov_matrix, verbose, risk_free_rate)
#     452         new_weights = np.asarray(weights)
#     453     else:
# --> 454         raise ValueError("Weights is None")
#     455
#     456     sigma = np.sqrt(objective_functions.portfolio_variance(new_weights, cov_matrix))
#
# ValueError: Weights is None

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 7th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu7, S7)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-28-690dc88f91dc> in <module>
#       1 ef = EfficientFrontier(mu7, S7)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu7.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-49e0c493fcbc> in <module>
# ----> 1 ret,vol,sharpe = ef.portfolio_performance(verbose=True)
#       2
#       3 mu7.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in portfolio_performance(self, verbose, risk_free_rate)
#     372         :rtype: (float, float, float)
#     373         """
# --> 374         return base_optimizer.portfolio_performance(
#     375             self.weights,
#     376             self.expected_returns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in portfolio_performance(weights, expected_returns, cov_matrix, verbose, risk_free_rate)
#     452         new_weights = np.asarray(weights)
#     453     else:
# --> 454         raise ValueError("Weights is None")
#     455
#     456     sigma = np.sqrt(objective_functions.portfolio_variance(new_weights, cov_matrix))
#
# ValueError: Weights is None

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 8th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu8, S8)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-30-f91945dbe1b3> in <module>
#       1 ef = EfficientFrontier(mu8, S8)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu8.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-9f35d6d54111> in <module>
# ----> 1 ret,vol,sharpe = ef.portfolio_performance(verbose=True)
#       2
#       3 mu8.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in portfolio_performance(self, verbose, risk_free_rate)
#     372         :rtype: (float, float, float)
#     373         """
# --> 374         return base_optimizer.portfolio_performance(
#     375             self.weights,
#     376             self.expected_returns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in portfolio_performance(weights, expected_returns, cov_matrix, verbose, risk_free_rate)
#     452         new_weights = np.asarray(weights)
#     453     else:
# --> 454         raise ValueError("Weights is None")
#     455
#     456     sigma = np.sqrt(objective_functions.portfolio_variance(new_weights, cov_matrix))
#
# ValueError: Weights is None

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 9th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu9, S9)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-32-0ebbe11d2e7a> in <module>
#       1 ef = EfficientFrontier(mu9, S9)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu9.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-17355dfa5061> in <module>
# ----> 1 ret,vol,sharpe = ef.portfolio_performance(verbose=True)
#       2
#       3 mu9.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in portfolio_performance(self, verbose, risk_free_rate)
#     372         :rtype: (float, float, float)
#     373         """
# --> 374         return base_optimizer.portfolio_performance(
#     375             self.weights,
#     376             self.expected_returns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in portfolio_performance(weights, expected_returns, cov_matrix, verbose, risk_free_rate)
#     452         new_weights = np.asarray(weights)
#     453     else:
# --> 454         raise ValueError("Weights is None")
#     455
#     456     sigma = np.sqrt(objective_functions.portfolio_variance(new_weights, cov_matrix))
#
# ValueError: Weights is None

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 10th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu10, S10)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-34-0af65d32f4ee> in <module>
#       1 ef = EfficientFrontier(mu10, S10)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu10.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-46de5c813e44> in <module>
# ----> 1 ret,vol,sharpe = ef.portfolio_performance(verbose=True)
#       2
#       3 mu10.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in portfolio_performance(self, verbose, risk_free_rate)
#     372         :rtype: (float, float, float)
#     373         """
# --> 374         return base_optimizer.portfolio_performance(
#     375             self.weights,
#     376             self.expected_returns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in portfolio_performance(weights, expected_returns, cov_matrix, verbose, risk_free_rate)
#     452         new_weights = np.asarray(weights)
#     453     else:
# --> 454         raise ValueError("Weights is None")
#     455
#     456     sigma = np.sqrt(objective_functions.portfolio_variance(new_weights, cov_matrix))
#
# ValueError: Weights is None

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 11th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu11, S11)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-36-9f40eb0cc12e> in <module>
#       1 ef = EfficientFrontier(mu11, S11)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu11.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-f7319d9eda74> in <module>
# ----> 1 ret,vol,sharpe = ef.portfolio_performance(verbose=True)
#       2
#       3 mu11.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in portfolio_performance(self, verbose, risk_free_rate)
#     372         :rtype: (float, float, float)
#     373         """
# --> 374         return base_optimizer.portfolio_performance(
#     375             self.weights,
#     376             self.expected_returns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in portfolio_performance(weights, expected_returns, cov_matrix, verbose, risk_free_rate)
#     452         new_weights = np.asarray(weights)
#     453     else:
# --> 454         raise ValueError("Weights is None")
#     455
#     456     sigma = np.sqrt(objective_functions.portfolio_variance(new_weights, cov_matrix))
#
# ValueError: Weights is None

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 12th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu12, S12)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-38-f9c15571c22d> in <module>
#       1 ef = EfficientFrontier(mu12, S12)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu12.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-382417f4c850> in <module>
# ----> 1 ret,vol,sharpe = ef.portfolio_performance(verbose=True)
#       2
#       3 mu12.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in portfolio_performance(self, verbose, risk_free_rate)
#     372         :rtype: (float, float, float)
#     373         """
# --> 374         return base_optimizer.portfolio_performance(
#     375             self.weights,
#     376             self.expected_returns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in portfolio_performance(weights, expected_returns, cov_matrix, verbose, risk_free_rate)
#     452         new_weights = np.asarray(weights)
#     453     else:
# --> 454         raise ValueError("Weights is None")
#     455
#     456     sigma = np.sqrt(objective_functions.portfolio_variance(new_weights, cov_matrix))
#
# ValueError: Weights is None

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 13th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu13, S13)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# <ipython-input-40-cce40dce6596> in <module>
#       1 ef = EfficientFrontier(mu13, S13)
#       2
# ----> 3 weight1a = ef.max_sharpe() #raw weights
#       4 cleanweight1a = ef.clean_weights() #cleaned weights
#       5 print(cleanweight1a)
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in max_sharpe(self, risk_free_rate)
#     224         ] + new_constraints
#     225
# --> 226         self._solve_cvxpy_opt_problem()
#     227         # Inverse-transform
#     228         self.weights = (self._w.value / k.value).round(16) + 0.0
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _solve_cvxpy_opt_problem(self)
#     227
#     228         if opt.status != "optimal":
# --> 229             raise exceptions.OptimizationError
#     230         self.weights = self._w.value.round(16) + 0.0  # +0.0 removes signed zero
#     231         return self._make_output_weights()
#
# OptimizationError: Please check your objectives/constraints or use a different solver.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu13.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-7abde0099759> in <module>
# ----> 1 ret,vol,sharpe = ef.portfolio_performance(verbose=True)
#       2
#       3 mu13.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in portfolio_performance(self, verbose, risk_free_rate)
#     372         :rtype: (float, float, float)
#     373         """
# --> 374         return base_optimizer.portfolio_performance(
#     375             self.weights,
#     376             self.expected_returns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in portfolio_performance(weights, expected_returns, cov_matrix, verbose, risk_free_rate)
#     452         new_weights = np.asarray(weights)
#     453     else:
# --> 454         raise ValueError("Weights is None")
#     455
#     456     sigma = np.sqrt(objective_functions.portfolio_variance(new_weights, cov_matrix))
#
# ValueError: Weights is None

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 14th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu14, S14)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# OrderedDict([('PRSSCOA HK Equity', 1.0), ('PRIHDSC HK Equity', 0.0)])
# Performance of function 1a portfolio in train period:

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu14.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# Expected annual return: 6.3%
# Annual volatility: 5.4%
# Sharpe Ratio: 0.79

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 15th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu15, S15)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# OrderedDict([('PRSSCOA HK Equity', 1.0), ('PRIHDSC HK Equity', 0.0)])
# Performance of function 1a portfolio in train period:

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu15.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# Expected annual return: 3.8%
# Annual volatility: 6.9%
# Sharpe Ratio: 0.25

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 16th five-year Backtesting  (for Function 1a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu16, S16)

weight1a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# OrderedDict([('PRSSCOA HK Equity', 1.0), ('PRIHDSC HK Equity', 0.0)])
# Performance of function 1a portfolio in train period:

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu16.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.
# Out:
# Expected annual return: 7.5%
# Annual volatility: 15.1%
# Sharpe Ratio: 0.37

# %% [markdown]
# ## Summary of Backtesting of Function 1a

# %%
perch_all = [perch1,perch2,perch3,perch4,perch5,perch6,perch7,perch8,perch9,perch10,perch11,perch12,perch13,perch14,perch15,perch16]
compare_all = [compare1,compare2,compare3,compare4,compare5,compare6,compare7,compare8,compare9,compare10,compare11,compare12,compare13,compare14,compare15,compare16]
mean_perch = sum(perch_all) / len(perch_all)
mean_compare = sum(compare_all) / len(compare_all)
print( "Function 1a Average error (%): " + str(mean_perch))
print( "Function 1a Average return compare to Benchmark(%): " + str(mean_compare))
#print( "Function 1a Accuracy (%): " + str(100-mean_perch))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-85ff86c13d07> in <module>
# ----> 1 perch_all = [perch1,perch2,perch3,perch4,perch5,perch6,perch7,perch8,perch9,perch10,perch11,perch12,perch13,perch14,perch15,perch16]
#       2 compare_all = [compare1,compare2,compare3,compare4,compare5,compare6,compare7,compare8,compare9,compare10,compare11,compare12,compare13,compare14,compare15,compare16]
#       3 mean_perch = sum(perch_all) / len(perch_all)
#       4 mean_compare = sum(compare_all) / len(compare_all)
#       5 print( "Function 1a Average error (%): " + str(mean_perch))
#
# NameError: name 'perch1' is not defined

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## Function 2a - Portfolio Optimization with given Risk Tolerance
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
ef = EfficientFrontier(mu1, S1)

ef.efficient_risk(target_volatility=0.1) #input desired volatility - default as ten percent
weights = ef.clean_weights()
weights

pd.Series(weights).plot.pie(figsize=(5,5))
plt.title("Fund Portfolio")
# Out:
# Text(0.5, 1.0, 'Fund Portfolio')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 1st five-year Backtesting  (for Function 2a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu15, S15)

weight2a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
# Out:
# OrderedDict([('PRSSCOA HK Equity', 1.0), ('PRIHDSC HK Equity', 0.0)])
# Performance of function 1a portfolio in train period:

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Function 3 - Minimise risk for a given return

# %%
ef = EfficientFrontier(mu, S, weight_bounds=(None, None))
ef.efficient_return(target_return=0.04, market_neutral=True)
weights = ef.clean_weights()
weights
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-f4cbd0d803ab> in <module>
# ----> 1 ef = EfficientFrontier(mu, S, weight_bounds=(None, None))
#       2 ef.efficient_return(target_return=0.04, market_neutral=True)
#       3 weights = ef.clean_weights()
#       4 weights
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/efficient_frontier.py in __init__(self, expected_returns, cov_matrix, weight_bounds, gamma, solver, verbose)
#     102                 raise ValueError("Covariance matrix does not match expected returns")
#     103
# --> 104         super().__init__(
#     105             len(tickers), tickers, weight_bounds, solver=solver, verbose=verbose
#     106         )
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in __init__(self, n_assets, tickers, weight_bounds, solver, verbose)
#     164         self._lower_bounds = None
#     165         self._upper_bounds = None
# --> 166         self._map_bounds_to_constraints(weight_bounds)
#     167
#     168         self._solver = solver
#
# /opt/anaconda3/lib/python3.8/site-packages/pypfopt/base_optimizer.py in _map_bounds_to_constraints(self, test_bounds)
#     185         ):
#     186             bounds = np.array(test_bounds, dtype=np.float)
# --> 187             self._lower_bounds = np.nan_to_num(bounds[:, 0], nan=-np.inf)
#     188             self._upper_bounds = np.nan_to_num(bounds[:, 1], nan=np.inf)
#     189         else:
#
# IndexError: too many indices for array

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Plotting Efficient Frontier

# %%
from pypfopt import CLA, plotting

cla = CLA(mu1, S1)
cla.max_sharpe()
cla.portfolio_performance(verbose=True);
# Out:
# Expected annual return: 2.6%
# Annual volatility: 3.9%
# Sharpe Ratio: 0.16

# %%
ax = plotting.plot_efficient_frontier(cla, showfig=False)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# # This scheme in a nutshell:

# %% [markdown]
# ##         Any portfolio with volatility higher than 11.1% is bad because you earn the same afterwards. The highest return you can get is 5.0%.

# %%
risktolerance, annualreturn = [], []
for rt2 in np.arange(0.02, 1, 0.001):
    ef = EfficientFrontier(mu, S)
    ef.efficient_risk(target_volatility=rt2)
    weights = ef.clean_weights()
    ret, volatility, Sharpe = ef.portfolio_performance(verbose=True)
    annualreturn.append(ret)
    risktolerance.append(rt2)
# Out:
# Expected annual return: 2.0%
# Annual volatility: 2.0%
# Sharpe Ratio: -0.02
# Expected annual return: 2.0%
# Annual volatility: 2.1%
# Sharpe Ratio: 0.02
# Expected annual return: 2.1%
# Annual volatility: 2.2%
# Sharpe Ratio: 0.05
# Expected annual return: 2.2%
# Annual volatility: 2.3%
# Sharpe Ratio: 0.08
# Expected annual return: 2.3%
# Annual volatility: 2.4%
# Sharpe Ratio: 0.11
# Expected annual return: 2.3%
# Annual volatility: 2.5%
# Sharpe Ratio: 0.13
# Expected annual return: 2.4%
# Annual volatility: 2.6%
# Sharpe Ratio: 0.15
# Expected annual return: 2.5%
# Annual volatility: 2.7%
# Sharpe Ratio: 0.18
# Expected annual return: 2.5%
# Annual volatility: 2.8%
# Sharpe Ratio: 0.19
# Expected annual return: 2.6%
# Annual volatility: 2.9%
# Sharpe Ratio: 0.21
# Expected annual return: 2.7%
# Annual volatility: 3.0%
# Sharpe Ratio: 0.23
# Expected annual return: 2.8%
# Annual volatility: 3.1%
# Sharpe Ratio: 0.24
# Expected annual return: 2.8%
# Annual volatility: 3.2%
# Sharpe Ratio: 0.26
# Expected annual return: 2.9%
# Annual volatility: 3.3%
# Sharpe Ratio: 0.27
# Expected annual return: 3.0%
# Annual volatility: 3.4%
# Sharpe Ratio: 0.28
# Expected annual return: 3.0%
# Annual volatility: 3.5%
# Sharpe Ratio: 0.29
# Expected annual return: 3.1%
# Annual volatility: 3.6%
# Sharpe Ratio: 0.30
# Expected annual return: 3.2%
# Annual volatility: 3.7%
# Sharpe Ratio: 0.31
# Expected annual return: 3.2%
# Annual volatility: 3.8%
# Sharpe Ratio: 0.32
# Expected annual return: 3.3%
# Annual volatility: 3.9%
# Sharpe Ratio: 0.33
# Expected annual return: 3.3%
# Annual volatility: 4.0%
# Sharpe Ratio: 0.34
# Expected annual return: 3.4%
# Annual volatility: 4.1%
# Sharpe Ratio: 0.34
# Expected annual return: 3.5%
# Annual volatility: 4.2%
# Sharpe Ratio: 0.35
# Expected annual return: 3.5%
# Annual volatility: 4.3%
# Sharpe Ratio: 0.36
# Expected annual return: 3.6%
# Annual volatility: 4.4%
# Sharpe Ratio: 0.36
# Expected annual return: 3.6%
# Annual volatility: 4.5%
# Sharpe Ratio: 0.37
# Expected annual return: 3.7%
# Annual volatility: 4.6%
# Sharpe Ratio: 0.37
# Expected annual return: 3.8%
# Annual volatility: 4.7%
# Sharpe Ratio: 0.38
# Expected annual return: 3.8%
# Annual volatility: 4.8%
# Sharpe Ratio: 0.38
# Expected annual return: 3.9%
# Annual volatility: 4.9%
# Sharpe Ratio: 0.38
# Expected annual return: 3.9%
# Annual volatility: 5.0%
# Sharpe Ratio: 0.38
# Expected annual return: 4.0%
# Annual volatility: 5.1%
# Sharpe Ratio: 0.38
# Expected annual return: 4.0%
# Annual volatility: 5.2%
# Sharpe Ratio: 0.38
# Expected annual return: 4.0%
# Annual volatility: 5.3%
# Sharpe Ratio: 0.38
# Expected annual return: 4.0%
# Annual volatility: 5.4%
# Sharpe Ratio: 0.38
# Expected annual return: 4.1%
# Annual volatility: 5.5%
# Sharpe Ratio: 0.38
# Expected annual return: 4.1%
# Annual volatility: 5.6%
# Sharpe Ratio: 0.38
# Expected annual return: 4.1%
# Annual volatility: 5.7%
# Sharpe Ratio: 0.37
# Expected annual return: 4.1%
# Annual volatility: 5.8%
# Sharpe Ratio: 0.37
# Expected annual return: 4.2%
# Annual volatility: 5.9%
# Sharpe Ratio: 0.37
# Expected annual return: 4.2%
# Annual volatility: 6.0%
# Sharpe Ratio: 0.36
# Expected annual return: 4.2%
# Annual volatility: 6.1%
# Sharpe Ratio: 0.36
# Expected annual return: 4.2%
# Annual volatility: 6.2%
# Sharpe Ratio: 0.36
# Expected annual return: 4.2%
# Annual volatility: 6.3%
# Sharpe Ratio: 0.36
# Expected annual return: 4.3%
# Annual volatility: 6.4%
# Sharpe Ratio: 0.35
# Expected annual return: 4.3%
# Annual volatility: 6.5%
# Sharpe Ratio: 0.35
# Expected annual return: 4.3%
# Annual volatility: 6.6%
# Sharpe Ratio: 0.35
# Expected annual return: 4.3%
# Annual volatility: 6.7%
# Sharpe Ratio: 0.35
# Expected annual return: 4.3%
# Annual volatility: 6.8%
# Sharpe Ratio: 0.34
# Expected annual return: 4.4%
# Annual volatility: 6.9%
# Sharpe Ratio: 0.34
# Expected annual return: 4.4%
# Annual volatility: 7.0%
# Sharpe Ratio: 0.34
# Expected annual return: 4.4%
# Annual volatility: 7.1%
# Sharpe Ratio: 0.34
# Expected annual return: 4.4%
# Annual volatility: 7.2%
# Sharpe Ratio: 0.33
# Expected annual return: 4.4%
# Annual volatility: 7.3%
# Sharpe Ratio: 0.33
# Expected annual return: 4.4%
# Annual volatility: 7.4%
# Sharpe Ratio: 0.33
# Expected annual return: 4.5%
# Annual volatility: 7.5%
# Sharpe Ratio: 0.33
# Expected annual return: 4.5%
# Annual volatility: 7.6%
# Sharpe Ratio: 0.32
# Expected annual return: 4.5%
# Annual volatility: 7.7%
# Sharpe Ratio: 0.32
# Expected annual return: 4.5%
# Annual volatility: 7.8%
# Sharpe Ratio: 0.32
# Expected annual return: 4.5%
# Annual volatility: 7.9%
# Sharpe Ratio: 0.32
# Expected annual return: 4.5%
# Annual volatility: 8.0%
# Sharpe Ratio: 0.32
# Expected annual return: 4.5%
# Annual volatility: 8.1%
# Sharpe Ratio: 0.31
# Expected annual return: 4.6%
# Annual volatility: 8.2%
# Sharpe Ratio: 0.31
# Expected annual return: 4.6%
# Annual volatility: 8.3%
# Sharpe Ratio: 0.31
# Expected annual return: 4.6%
# Annual volatility: 8.4%
# Sharpe Ratio: 0.31
# Expected annual return: 4.6%
# Annual volatility: 8.5%
# Sharpe Ratio: 0.31
# Expected annual return: 4.6%
# Annual volatility: 8.6%
# Sharpe Ratio: 0.30
# Expected annual return: 4.6%
# Annual volatility: 8.7%
# Sharpe Ratio: 0.30
# Expected annual return: 4.6%
# Annual volatility: 8.8%
# Sharpe Ratio: 0.30
# Expected annual return: 4.7%
# Annual volatility: 8.9%
# Sharpe Ratio: 0.30
# Expected annual return: 4.7%
# Annual volatility: 9.0%
# Sharpe Ratio: 0.30
# Expected annual return: 4.7%
# Annual volatility: 9.1%
# Sharpe Ratio: 0.30
# Expected annual return: 4.7%
# Annual volatility: 9.2%
# Sharpe Ratio: 0.29
# Expected annual return: 4.7%
# Annual volatility: 9.3%
# Sharpe Ratio: 0.29
# Expected annual return: 4.7%
# Annual volatility: 9.4%
# Sharpe Ratio: 0.29
# Expected annual return: 4.7%
# Annual volatility: 9.5%
# Sharpe Ratio: 0.29
# Expected annual return: 4.8%
# Annual volatility: 9.6%
# Sharpe Ratio: 0.29
# Expected annual return: 4.8%
# Annual volatility: 9.7%
# Sharpe Ratio: 0.29
# Expected annual return: 4.8%
# Annual volatility: 9.8%
# Sharpe Ratio: 0.28
# Expected annual return: 4.8%
# Annual volatility: 9.9%
# Sharpe Ratio: 0.28
# Expected annual return: 4.8%
# Annual volatility: 10.0%
# Sharpe Ratio: 0.28
# Expected annual return: 4.8%
# Annual volatility: 10.1%
# Sharpe Ratio: 0.28
# Expected annual return: 4.8%
# Annual volatility: 10.2%
# Sharpe Ratio: 0.28
# Expected annual return: 4.9%
# Annual volatility: 10.3%
# Sharpe Ratio: 0.28
# Expected annual return: 4.9%
# Annual volatility: 10.4%
# Sharpe Ratio: 0.28
# Expected annual return: 4.9%
# Annual volatility: 10.5%
# Sharpe Ratio: 0.27
# Expected annual return: 4.9%
# Annual volatility: 10.6%
# Sharpe Ratio: 0.27
# Expected annual return: 4.9%
# Annual volatility: 10.7%
# Sharpe Ratio: 0.27
# Expected annual return: 4.9%
# Annual volatility: 10.8%
# Sharpe Ratio: 0.27
# Expected annual return: 4.9%
# Annual volatility: 10.9%
# Sharpe Ratio: 0.27
# Expected annual return: 4.9%
# Annual volatility: 11.0%
# Sharpe Ratio: 0.27
# Expected annual return: 5.0%
# Annual volatility: 11.1%
# Sharpe Ratio: 0.27
# Expected annual return: 5.0%
# Annual volatility: 11.2%
# Sharpe Ratio: 0.27
# Expected annual return: 5.0%
# Annual volatility: 11.3%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.4%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# ...
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26
# Expected annual return: 5.0%
# Annual volatility: 11.5%
# Sharpe Ratio: 0.26

# %%
plt.plot(annualreturn, risktolerance)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
